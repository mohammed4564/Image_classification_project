# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'C:/Users/lenovo/OneDrive - DATANOVELTECH PRIVATE LIMITED/Desktop/Project folders/image_classification_project/Fruits_Vegetables/train'
data_test_path = 'C:/Users/lenovo/OneDrive - DATANOVELTECH PRIVATE LIMITED/Desktop/Project folders/image_classification_project/Fruits_Vegetables/test'
data_val_path = 'C:/Users/lenovo/OneDrive - DATANOVELTECH PRIVATE LIMITED/Desktop/Project folders/image_classification_project/Fruits_Vegetables/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dropout(0.2),
    
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 48s 464ms/step - accuracy: 0.0483 - loss: 4.5283 - val_accuracy: 0.1766 - val_loss: 3.1790
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 44s 444ms/step - accuracy: 0.1839 - loss: 3.0079 - val_accuracy: 0.4302 - val_loss: 2.0607
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 423ms/step - accuracy: 0.3722 - loss: 2.2487 - val_accuracy: 0.7550 - val_loss: 1.1758
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.6268 - loss: 1.3625 - val_accuracy: 0.8775 - val_loss: 0.6554
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 414ms/step - accuracy: 0.7884 - loss: 0.7715 - val_accuracy: 0.9060 - val_loss: 0.5091
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 44s 445ms/step - accuracy: 0.8643 - loss: 0.4641 - val_accuracy: 0.9088 - val_loss: 0.4952
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 436ms/step - accuracy: 0.9008 - loss: 0.3730 - val_accuracy: 0.9231 - val_loss: 0.4558
# Epoch 8/25
# ...

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'chilli.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 image = 'chilli.jpg'
# ----> 2 image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
#       3 img_arr = tf.keras.utils.array_to_img(image)
#       4 img_bat=tf.expand_dims(img_arr,0)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chilli.jpg'

# %%
predict = model.predict(img_bat)

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))

# %%
model.save('Image_classify.keras')
